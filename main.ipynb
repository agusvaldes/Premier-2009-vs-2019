# %%
import pandas
import Functions

# %%
premier2009 = pandas.read_csv('2000-2009.csv')
premier2019 = pandas.read_csv('2010-2019.csv')

# %%
# Ganadores de la premier league (Gráfico circular)
Functions.winning_clubs(data=premier2009, title='2000 - 2009 Ganadores')
Functions.winning_clubs(data=premier2019, title='2010 - 2019 Ganadores')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Ganadores de la premier league (Gráfico circular)
# ----> 2 Functions.winning_clubs(data=premier2009, title='2000 - 2009 Ganadores')
#       3 Functions.winning_clubs(data=premier2019, title='2010 - 2019 Ganadores')
#
# File c:\Users\agusv\OneDrive\Escritorio\Proyectos personales DS\fulbo\Premier 2009 vs 2019\Functions.py:71, in winning_clubs(data, title)
#      69 def winning_clubs(data, title):
#      70     winners = data.team[data.position == 1].value_counts()
# ---> 71     draw_pie_chart(labels=winners.index, values=winners, title=title)
#
# File c:\Users\agusv\OneDrive\Escritorio\Proyectos personales DS\fulbo\Premier 2009 vs 2019\Functions.py:41, in draw_pie_chart(labels, values, title)
# ...

# %%
# Equipos que más veces clasificaron para la UCL (gráfico de barras)
Functions.champions_league_clubs(data=premier2009, title='2000 - 2009 UCL')
Functions.champions_league_clubs(data=premier2019, title='2010 - 2019 UCL')

# %%
# Equipos descendidos (gráfico de barras)
Functions.worst_clubs(data=premier2009, title='2000 - 2009 Descenso')
Functions.worst_clubs(data=premier2019, title='2010 - 2019 Descenso')

# %%
# Equipos que más partidos ganaron (gráfico de barras)
Functions.most_in(data=premier2009, series='won', title='2000 - 2009 Victorias')
Functions.most_in(data=premier2019, series='won', title='2010 - 2019 Victorias')

# %%
# Equipos que más partidos empataron (gráfico de barras)
Functions.most_in(data=premier2009, series='draw', title='2000 - 2009 Empates')
Functions.most_in(data=premier2019, series='draw', title='2010 - 2019 Empates')

# %%
# Equipos que más veces perdieron (gráfico de barras)
Functions.most_in(data=premier2009, series='lost', title='2000 - 2009 Derrotas')
Functions.most_in(data=premier2019, series='lost', title='2010 - 2019 Derrotas')

# %%
# Equipos con más goles a favor (gráfico de barras)
Functions.most_in(data=premier2009, series='gf', title='2000 - 2009 Goles a favor')
Functions.most_in(data=premier2019, series='gf', title='2010 - 2019 Goles a favor')

# %%
# Equipos con más goles en contra (gráfico de barras)
Functions.most_in(data=premier2009, series='ga', title='2000 - 2009 Goles en contra')
Functions.most_in(data=premier2019, series='ga', title='2010 - 2019 Goles en contra')

# %%
# Equipos con más puntos (gráfico de barras)
Functions.most_in(data=premier2009, series='points', title='2000 - 2009 Puntos')
Functions.most_in(data=premier2019, series='points', title='2010 - 2019 Puntos')

# %%
# Rendimiento de los equipos debido a los puntos
Functions.team_performance(data=premier2009, team='Manchester United', title='Manchester United 2000-2009')
Functions.team_performance(data=premier2019, team='Manchester United', title='Manchester United 2010-2019')

Functions.team_performance(data=premier2009, team='Manchester City', title='Manchester City 2000-2009')
Functions.team_performance(data=premier2019, team='Manchester City', title='Manchester City 2010-2019')

Functions.team_performance(data=premier2009, team='Chelsea', title='Chelsea 2000-2009')
Functions.team_performance(data=premier2019, team='Chelsea', title='Chelsea 2010-2019')

Functions.team_performance(data=premier2009, team='Liverpool', title='Liverpool 2000-2009')
Functions.team_performance(data=premier2019, team='Liverpool', title='Liverpool 2010-2019')

Functions.team_performance(data=premier2009, team='Arsenal', title='Arsenal 2000-2009')
Functions.team_performance(data=premier2019, team='Arsenal', title='Arsenal 2010-2019')

Functions.team_performance(data=premier2009, team='Tottenham Hotspur ', title='Tottenham Hotspur 2000-2009')
Functions.team_performance(data=premier2019, team='Tottenham Hotspur ', title='Tottenham Hotspur 2010-2019')
